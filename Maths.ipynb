# %%
a = int(input("First number: "))
b = int(input("Second number: "))

sum = a+b
diff = a-b
pro = a*b

print(f"Sum: {sum}   Diff: {diff}  Pro: {pro}")
# Out:
# First number: 3
# Second number: 2
# Sum: 5   Diff: 1  Pro: 6

# %%
quo = a/b
rem = a%b
print(f"Quo: {quo}   Remin: {rem}")
# Out:
# Quo: 1.5   Remin: 1

# %%
rad = int(input("Whats the radius"))
area = 3.14*rad**2
print(f"Area: {area}")
# Out:
# Whats the radius4
# Area: 50.24

# %%
f = int(input("First:"))
h = int(input("Second:"))
g = int(input("Third:"))

ave = (f+g+h) / 3
print(f"Average: {ave}")
# Out:
# First:3
# Second:5
# Third:3
# Average: 3.6666666666666665

# %%
cel = int(input("Celsius: "))
faren = (cel*(9/5))+32
print(f"Faren: {faren}")
# Out:
# Celsius: 54
# Faren: 129.2

# %%
faren = int(input("faren: "))
cel = (faren - 32) / 1.8
print(f"Celsius: {cel}")
# Out:
# faren: 56
# Celsius: 13.333333333333332

# %%
a = 10
b = 3
c = a/b

d = a//b

print(f"{c}  {d}")
# Out:
# 3.3333333333333335  3
