# %%
amount = float(input("Enter amount: "))
interest = float(input("Enter interest: "))
years = float(input("Enter years: "))

int = float(((amount * interest * years) / 100))
print(f"SI = {int}")
# Out:
# Enter amount: 50000
# Enter interest: 5
# Enter years: 2
# SI = 5000.0
